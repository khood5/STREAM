# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import copy
from LangDataloader import LangDataloader
# %matplotlib inline
defultePlotSize = plt.rcParams['figure.figsize']
oringalFontSize = matplotlib.rcParams['font.size']

# %% [markdown]
# ## this is a note book for exploring the data in Prepocessing/Data/allData/Topcoder_Data
#
# <em><b>Objective:</b></em> To develop language classifier that correctly identify the languages spoken in audio recordings. Given speech data from multiple languages, the classifier must identify which languages are spoken. The competition asks for three best possible spoken languages per test audio files.
#
# <em><b>Dataset:</b></em> It has 66,176 speech files (.mp3) as training dataset of 176 languages, each language has 376 samples of 10 sec. And has 12,320 speech files (.mp3) as test dataset of 10 sec. Unfortunately, it <u>doesn’t</u> have Nepali language speech files.

# %% [markdown]
# <table>
# <tr><td><table>
# <tr><th>Language</th><th>Number of Samples</th></tr>
# <tr><td>Adiokrou</td><td>376</td></tr>
# <tr><td>Aguaruna Awajun</td><td>376</td></tr>
# <tr><td>Akha</td><td>376</td></tr>
# <tr><td>Akoose</td><td>376</td></tr>
# <tr><td>Alangan</td><td>376</td></tr>
# <tr><td>Albanian Tosk</td><td>376</td></tr>
# <tr><td>Alladian</td><td>376</td></tr>
# <tr><td>Altai Southern</td><td>376</td></tr>
# <tr><td>Anufo</td><td>376</td></tr>
# <tr><td>Arabic</td><td>376</td></tr>
# <tr><td>Arabic Egyptian Spoken</td><td>376</td></tr>
# <tr><td>Arabic Sudanese Spoken</td><td>376</td></tr>
# <tr><td>Aruamu</td><td>376</td></tr>
# <tr><td>Ashaninca</td><td>376</td></tr>
# <tr><td>Avokaya</td><td>376</td></tr>
# <tr><td>Awa PNG</td><td>376</td></tr>
# <tr><td>Awadhi</td><td>376</td></tr>
# <tr><td>Aymara</td><td>376</td></tr>
# <tr><td>Azerbaijani North</td><td>376</td></tr>
# <tr><td>Bali</td><td>376</td></tr>
# <tr><td>Bekwarra</td><td>376</td></tr>
# <tr><td>Belize Kriol English</td><td>376</td></tr>
# <tr><td>Bench</td><td>376</td></tr>
# <tr><td>Bhojpuri</td><td>376</td></tr>
# <tr><td>Biate</td><td>376</td></tr>
# <tr><td>Bicolano Central</td><td>376</td></tr>
# <tr><td>Bokyi</td><td>376</td></tr>
# <tr><td>Bora</td><td>376</td></tr>
# <tr><td>Bru Eastern</td><td>376</td></tr>
# <tr><td>Cakchiquel South Central</td><td>376</td></tr>
# <tr><td>CandoshiShapra</td><td>376</td></tr>
# <tr><td>Carib</td><td>376</td></tr>
# <tr><td>Chamacoco</td><td>376</td></tr>
# <tr><td>Chayahuita Shawi</td><td>376</td></tr>
# <tr><td>Chinantec de Usila</td><td>376</td></tr>
# <tr><td>Chipaya</td><td>376</td></tr>
# <tr><td>Chuj Ixtatan</td><td>376</td></tr>
# <tr><td>Cofan</td><td>376</td></tr>
# <tr><td>Dan East</td><td>376</td></tr>
# <tr><td>Sanuma</td><td>376</td></tr>
# <tr><td>Sasak</td><td>376</td></tr>
# <tr><td>Sauria Paharia</td><td>376</td></tr>
# <tr><td>Sebat Bet Gurage_Gurage Chaha</td><td>376</td></tr>
# <tr><td>Shilluk</td><td>376</td></tr>
# <tr><td>ShipiboConibo</td><td>376</td></tr>
# <tr><td>Shuar</td><td>376</td></tr>
# <tr><td>Tamasheq</td><td>376</td></tr>
# <tr><td>Tektiteko</td><td>376</td></tr>
# <tr><td>Tepehua Pisaflores</td><td>376</td></tr>
# <tr><td>Tepehua Tlachichilco</td><td>376</td></tr>
# <tr><td>Terena</td><td>376</td></tr>
# <tr><td>Teribe</td><td>376</td></tr>
# <tr><td>Teso</td><td>376</td></tr>
# <tr><td>Thai</td><td>376</td></tr>
# <tr><td>Themne</td><td>376</td></tr>
# <tr><td>Ticuna</td><td>376</td></tr>
# <tr><td>Tobelo</td><td>376</td></tr>
# <tr><td>Tol</td><td>376</td></tr>
# <tr><td>Totonac Highland</td><td>376</td></tr>
# <tr><td>Trio</td><td>376</td></tr>
# <tr><td>Tucano</td><td>376</td></tr>
# <tr><td>Tuva</td><td>376</td></tr>
# <tr><td>Tzeltal Bachajon</td><td>376</td></tr>
# <tr><td>Vai</td><td>376</td></tr>
# <tr><td>Vietnamese</td><td>376</td></tr>
# <tr><td>Waimaha</td><td>376</td></tr>
# <tr><td>Waiwai</td><td>376</td></tr>
# <tr><td>Wichi Lhamtes Nocten Weenhayek</td><td>376</td></tr>
# <tr><td>Yali Angguruk</td><td>376</td></tr>
# <tr><td>Yawa</td><td>376</td></tr>
# <tr><td>Zapotec Isthmus</td><td>376</td></tr>
# <tr><td>Zapotec Sierra de Juarez</td><td>376</td></tr>
# </table></td></tr>
# </table>
#
# #### Grand Total: 66176

# %% [markdown]
# The document, topcoder_summary, with the data seems to be pretty informative. Apprently topcoder is a private company that competed in some compitation to get the highest accruacy on this data. They where unable to give a winning solution but they listed two others

# %% [markdown]
# <table>
# <tr><td>
# Rank 1
# He has used Gaussian Mixture Model to trained the data and used logistic regression as final step to calibrate the individual GMM's prediction
# <ul>
# <li>https://github.com/CatalinTiseanu/spoken-language-identification</li>
# <li>https://github.com/CatalinTiseanu/spoken-language-identification/blob/master/SpokenLanguages2%20-%20report.pdf</li>
# </ul>
# The main points about his solution are:
# <ol>
# <li>Use sox to convert the mp3’s to wav</li>
# <li>Use sphinx_fe to extract 13 Mel Frequency Cepstral Coefficients (MFCC) features</li>
# <li>Train a Gaussian Mixture Model with 2048 mixtures for each language feature matrix.</li>
# <li>Finally, calibrate the individual language predictions using Logistic Regression</li>
# </ol>
#
# </td><td>
# Rank 10
# Rank 10 winner who had acclaimed 95% accuracy in training data. Please find the solution and code at Github.
# <ul>
# <li>https://yerevann.github.io/2015/10/11/spoken-language-identification-with-deep-convolutional-networks/</li>
# <li>https://github.com/YerevaNN/Spoken-language-identification</li>
# </ul>
# The main points about his solution are.
# <ol>
# <li>Used Deep Convolutional Network (Machine Vision).</li>
# <li>Converted mp3 to wav and created spectrogram of a wav file.</li>
# <li>Spent lot of effort on learning rate and data augmentation.</li>
# <li>Used ensemble as final submission.</li>
# </ol>
# </td></tr>
# </table>

# %% [markdown]
# It looks like the testing data index file is missing classes

# %% [markdown]
# Useful library is the Librosa library for audio handling
#
# It seems like we can start by exstracting 3 features Melspectrogram (similar to the rank 1 soltion), Spectral Centroid, and Spectral Flatness. This was found <a href="https://mct-master.github.io/machine-learning/2019/09/16/ML-Dry-Wet-Sound-Classification.html">here</a>

# %%
smallDataSet = [["000kouqjfnk.mp3","Hmong Daw"],
["000w3fewuqj.mp3","Tektiteko"],
["000ylhu4sxl.mp3","Teribe"],
["0014x3zvjrl.mp3","Chipaya"],
["001xjmtk2wx.mp3","KalmykOirat"],
["002hrjhbsnk.mp3","Gidar"],
["002sjun3mz4.mp3","Dutch"],
["003b3pbg4nq.mp3","Konso"]]

traingDataBasesPath = "/home/khood/GitHub/STREAM/Prepocessing/Data/trainingdata/Training_data/"
y, sr = librosa.load(traingDataBasesPath+smallDataSet[0][0]) # returns y: audio time series. Multi-channel is supported. sr: sampling rate of y
y
# Out:
# array([ 1.8431437e-18,  1.4094628e-18, -3.0899762e-18, ...,
#        -3.1994008e-03, -5.7544569e-03, -4.0281997e-03], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)

# %% [markdown]
# This is a compairson of the melspectrogram of some trainging data

# %%
plt.rcParams['figure.figsize'] = [100, 80]
matplotlib.rcParams.update({'font.size': 45})
# plt.subplot(1, 2, 1)
# (<Figure size 10000x4000 with 1 Axes>, <Axes: >)
fig, axs = plt.subplots(4,2)
figSamples = copy.deepcopy(smallDataSet)
fig.tight_layout(pad=2.0)
for row in axs:
    for col in row:
        data = figSamples.pop(0)
        y, sr = librosa.load(traingDataBasesPath+data[0])
        S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
        S_dB = librosa.power_to_db(S, ref=np.max)
        img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=8000, ax=col)
        fig.colorbar(img, ax=col, format='%+2.0f dB')
        col.set(title=f"Mel-frequency spectrogram {data[1]}")
plt.rcParams['figure.figsize'] = defultePlotSize
matplotlib.rcParams.update({'font.size': oringalFontSize})

# %% [markdown]
# now we take these and use them as our raw data

# %%
y, sr = librosa.load(traingDataBasesPath+smallDataSet[0][0])
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
S.shape
# Out:
# (128, 430)

# %%
indexFile = "/home/khood/GitHub/STREAM/Prepocessing/processedData/trainingData.csv"
traingDataBasesPath
data = LangDataloader(indexFile,traingDataBasesPath)
# data = LangDataloader("/home/khood/GitHub/STREAM/Prepocessing/outTmp/index.csv","/home/khood/GitHub/STREAM/Prepocessing/outTmp/")

# %%
print(data[0])
data[0][0].shape
# Out:
# (array([[2.63883101e-19, 1.22818531e-12, 1.39712152e-04, ...,
#         1.94925320e-04, 2.14243788e-04, 8.37661719e-05],
#        [1.92740993e-19, 2.09947251e-12, 1.88039092e-04, ...,
#         6.06049798e-05, 1.19677730e-04, 4.57019196e-05],
#        [3.17086867e-19, 2.67086635e-12, 1.46583782e-03, ...,
#         7.10580789e-05, 5.90178679e-05, 3.53426731e-05],
#        ...,
#        [6.34432666e-20, 2.68980103e-16, 2.00535890e-08, ...,
#         1.16681967e-07, 1.17891261e-07, 1.18530444e-07],
#        [8.06820273e-20, 1.49428820e-15, 1.14662351e-08, ...,
#         1.63052164e-07, 2.28543470e-07, 1.89547364e-07],
#        [7.90790029e-20, 3.91833132e-13, 9.87008946e-08, ...,
#         2.16024517e-07, 2.19754043e-07, 1.28905526e-07]]), array(['test'], dtype='<U4'))
# (128, 430)

# %%
listData = []
lastStep = 0
for step in list(range(0,len(data),100)):
    for file in range(len(data))[lastStep:step]:
        print(f"adding {lastStep} to {step} of {len(data)}: {'{0:.0f}%'.format(step/len(data) * 100)}... ",end="\x1b\r")
        listData.append(data[file])
    lastStep = step
        
for file in range(len(data))[lastStep:]: # grab the remaning (if the size%stepSize != 0 then there will be some left over)
    print(f"adding {lastStep} to {len(data)} of {len(data)}: {'{0:.0f}%'.format(step/len(data) * 100)}... ",end="\x1b\r")
    listData.append(data[file])
    
listData
# Out:
# adding 66100 to 66176 of 66176: 100%...
# [(array([[3.75514827e-20, 2.56857822e-13, 8.81158303e-06, ...,
#           5.18449470e-02, 5.43518774e-02, 2.33962551e-01],
#          [3.74744418e-20, 1.16276834e-12, 2.63696074e-05, ...,
#           1.06346868e-01, 2.03390885e-02, 2.69254118e-01],
#          [3.52366889e-20, 2.22563396e-12, 3.55555603e-05, ...,
#           2.19644651e-01, 1.41782835e-02, 3.17456096e-01],
#          ...,
#          [1.76972675e-20, 4.17392791e-13, 1.73597270e-09, ...,
#           8.89725285e-04, 4.50391672e-04, 4.18557669e-04],
#          [1.46907422e-20, 1.52982303e-12, 4.97249486e-09, ...,
#           2.29475540e-04, 1.26485669e-04, 2.05114717e-04],
#          [2.23270790e-21, 8.79270886e-13, 1.69727943e-09, ...,
#           1.65553749e-04, 7.10123422e-05, 1.46182065e-04]], dtype=float32),
#   array(['Hmong Daw'], dtype='<U9')),
#  (array([[1.4830992e-18, 4.7984713e-11, 3.1976026e-04, ..., 2.6271574e-03,
#           8.1909850e-04, 1.6048369e-04],
# ...

# %%
aShape = listData[0][0].shape
aShape
# Out:
# (128, 430)

# %%
j = 0
for i in listData:
    print(f"checking... {j}",end="\x1b\r")
    assert aShape == i[0].shape
    j = j + 1
# Out:
# checking... 66175

# %% [markdown]
# Looks like they are the same size each image.
